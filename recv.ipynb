# %%
from infra import Magic_serial

# %%
b = Magic_serial('/dev/ttyUSB1')

# %%
b.receive_frame(10)
# Out:
# header: b'\x00\x01\xb0|\x00\x05\xda\x94|\x03'
# 3609018595
# 3667164163
# b'\x00\x01\xb0|'
# (b'hello', 0, 1, 5, 'f7c5ef95fe4845391faf72af59b25450')
